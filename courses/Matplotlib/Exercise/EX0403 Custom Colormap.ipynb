# %% [markdown]
# # 사용자 지정 Colormap 을 사용해서 Colorbar 를 그릴 수 있다.

# %%
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(1)
data = np.random.rand(14,16)

# %% [markdown]
# ## 1. 이산형 컬러맵을 사용한  Colorbar

# %%
my_discrete_cmap = ListedColormap(["red", "magenta", "purple", "orange", "dodgerblue"])

fig, ax = plt.subplots()
im = ax.imshow(data, cmap=my_discrete_cmap)

ax.set_xlabel("x")
cb = fig.colorbar(im, pad=0.05)

# %% [markdown]
# ## 2. 연속형 컬러맵을 사용한 Colorbar

# %%
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

colors = ["red", "magenta", "purple", "orange", "dodgerblue"]
nodes = [0.0,0.25,0.5,0.75,1.0]
my_continuous_cmap = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))

fig, ax = plt.subplots()
im = ax.imshow(data, cmap=my_continuous_cmap)

ax.set_xlabel("x")
cb = fig.colorbar(im, pad=0.05)

# %% [markdown]
# ## 3. Two-Color 컬러맵을 사용한 Colorbar

# %%
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
colors = ["white", "dodgerblue"]
nodes = [0.0,1.0]
twocolor_cmap = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))

fig, ax = plt.subplots()
im = ax.imshow(data, cmap=twocolor_cmap)

ax.set_xlabel("x")
cb = fig.colorbar(im, pad=0.05)

# %%
colors = ["magenta", "orange"]
nodes = [0.0,1.0]
twocolor_cmap = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))

fig, ax = plt.subplots()
im = ax.imshow(data, cmap=twocolor_cmap)

ax.set_xlabel("x")
cb = fig.colorbar(im, pad=0.05)

# %% [markdown]
# #### Matplotlib 에서 색상표는 다음에서 찾을 수 있다.
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %% [markdown]
# #### 실습1. 두 가지 색상을 사용해서 위의 Colorbar 를 다시 그려보자. (본인이 원하는 색상)

# %% [markdown]
# #### 실습2. 4 가지 색상을 사용해서 위의 Colorbar 를 다시 그려보자. (본인이 원하는 색상)

# %% [markdown]
# #### 실습3. 위의 실습1. 2. 를 이산형 컬러맵으로 다시 진행해 보자.
