# %% [markdown]
# - reference :// https://pabloinsente.github.io/intro-numpy-fundamentals

# %%
import numpy as np

# %% [markdown]
# # 3. Vectorization
# - Numpy 의 Vectorization 이 Looping 에 비해 얼마나 효율적인지 확인해 보자.

# %%
x = np.random.rand(100)
y = np.random.rand(100)

# %%
# %%timeit
for i in range(0, len(x)):
    x[i] + y[i]
# Out:
# 33.3 µs ± 1.13 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
x+y;
# Out:
# 854 ns ± 216 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
